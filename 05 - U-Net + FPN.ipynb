# %% [markdown]
# # Libraries

# %%
# System Libraries
import os
import glob
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import graphviz
from IPython.display import Image

# Metrics and Preprocessing
import cv2
from sklearn.utils import shuffle
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import sklearn.metrics as skmetrics
from sklearn.metrics import jaccard_score, f1_score

# Deep Learning Libraries
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import mixed_precision
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import (
    Add, Input, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Dropout,
    concatenate, BatchNormalization, UpSampling2D
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

# %%
# Check Tensorflow Version
print(tf.__version__)

import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2.16.1
# Num GPUs Available:  1

# %% [markdown]
# # Configurations

# %%
# Enable mixed precision training
# mixed_precision.set_global_policy('mixed_float16')

# Data setup
DATA_DIR = r'/kaggle/input/leukemia/Original'
MASK_DIR = r'/kaggle/input/leukemia/Segmented'
CLASSES = ['Benign', 'Early', 'Pre', 'Pro']

# Image dimensions
SIZE_X = 224
SIZE_Y = 224
CHANNELS = 3
IMG_SHAPE = (SIZE_X, SIZE_Y, CHANNELS)
N_CLASSES = 1

# Set batch size and other hyperparameters
N_FILTERS = 32
BATCH_SIZE = 32  
EPOCHS = 35  
LEARNING_RATE = 0.001
DROPOUT_RATE = 0.4
EXPERIMENT_NAME = "U-Net_FPN_Leukemia_Segmentation"

# %% [markdown]
# # Data Pre-Processing

# %%
# Load and preprocess all images and masks
images = []
masks = []

# Load and preprocess images
for class_name in CLASSES:
    class_dir = os.path.join(DATA_DIR, class_name)
    mask_class_dir = os.path.join(MASK_DIR, class_name)
    
    if not os.path.exists(class_dir) or not os.path.exists(mask_class_dir):
        continue
        
    for img_name in sorted(os.listdir(class_dir)):
        # Process image
        img_path = os.path.join(class_dir, img_name)
        mask_path = os.path.join(mask_class_dir, img_name)
        
        if not os.path.exists(mask_path):
            continue
            
        # Load and preprocess image
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        img = img.astype(np.float32) / 255.0
        images.append(img)
        
        # Load and preprocess mask
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X), interpolation=cv2.INTER_NEAREST)
        mask = (mask > 128).astype(np.uint8)  # Binary threshold
        masks.append(mask)

images = np.array(images)
masks = np.array(masks)

# %%
# Ensure masks are binary
masks = (masks > 0).astype(np.float32)

# Add channel dimension
masks_input = np.expand_dims(masks, axis=-1)  # Shape: (num_samples, height, width, 1)

# Split dataset into train+val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(
    images, masks_input, test_size=0.15, shuffle=True, random_state=42
)

# Calculate the proportion for validation set from the train+val data
val_size = 0.15 / (1 - 0.15)  # val_size = 0.15 / 0.85

# Split train+val into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=val_size, random_state=42
)

# %%
# Create TensorFlow datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_ds = train_ds.shuffle(1000).batch(BATCH_SIZE)

val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(BATCH_SIZE)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE)

# %%
# Display sample images and their corresponding masks
plt.figure(figsize=(15, 10))

# Display images
for i in range(5):
    plt.subplot(5, 5, 1 + 5 + i)
    plt.axis('off')
    plt.imshow(images[i])
    plt.title(f'Original Image {i+1}')
              
# Display masks
for i in range(5):
    plt.subplot(5, 5, 1 + i)
    plt.axis('off')
    plt.imshow(masks[i], cmap='gray')
    plt.title(f'Mask {i+1}')
    
plt.show()

# %%
# Verify data information
print(f'IMAGES:\n'
      f'Unique values: {np.unique(images)}\n'
      f'Shape: {images.shape}\n'
#  0.87058824 0.8745098  0.8784314  0.88235295 0.8862745  0.8901961
#  0.89411765 0.8980392  0.9019608  0.90588236 0.9098039  0.9137255
#  0.91764706 0.92156863 0.9254902  0.92941177 0.93333334 0.9372549
#  0.9411765  0.94509804 0.9490196  0.9529412  0.95686275 0.9607843
#  0.9647059  0.96862745 0.972549   0.9764706  0.98039216 0.9843137
#  0.9882353  0.99215686 0.99607843 1.        ]
# Shape: (3256, 224, 224, 3)
# Type: float32
#
# MASKS:
# Unique values: [0. 1.]
# Shape: (3256, 224, 224)
# Type: float32

# %%
# Print final dataset information
print(f'Final dataset shapes:')
print(f'TRAIN SET:\n'
      f'X_train shape: {X_train.shape}\n'
      f'y_train shape: {y_train.shape}\n\n'
      f'VALIDATION SET:\n'
      f'X_val shape: {X_val.shape}\n'
      f'y_val shape: {y_val.shape}\n\n'
      f'TEST SET:\n'
      f'X_test shape: {X_test.shape}\n'
      f'y_test shape: {y_test.shape}')
# Out:
# Final dataset shapes:
# TRAIN SET:
# X_train shape: (2278, 224, 224, 3)
# y_train shape: (2278, 224, 224, 1)
#
# VALIDATION SET:
# X_val shape: (489, 224, 224, 3)
# y_val shape: (489, 224, 224, 1)
#
# TEST SET:
# X_test shape: (489, 224, 224, 3)
# y_test shape: (489, 224, 224, 1)

# %%
# Sizes of each dataset
sizes = [len(X_train), len(X_val), len(X_test)]
labels = ['Train Set', 'Validation Set', 'Test Set']
colors = ['#7FC8A9','#FFD166','#EF476F']
explode = (0.1, 0, 0)  # explode the 1st slice (Train Set)

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=140)
plt.title('Dataset Distribution')
plt.show()

# %% [markdown]
# # U-Net

# %%
# Convolutional Block (Double Convolution)
def double_conv_block(x, N_FILTERS):
    x = Conv2D(N_FILTERS, 3, padding="same", activation="relu", kernel_initializer="he_normal")(x)
    x = Conv2D(N_FILTERS, 3, padding="same", activation="relu", kernel_initializer="he_normal")(x)
    return x

# Downsample Block (Conv + MaxPooling)
def downsample_block(x, N_FILTERS):
    f = double_conv_block(x, N_FILTERS)
    p = MaxPooling2D(2)(f)
    return f, p

# Upsample Block (Transposed Conv + Concatenate + Double Convolution)
def upsample_block(x, conv_features, N_FILTERS):
    x = Conv2DTranspose(N_FILTERS, 3, 2, padding="same")(x)
    x = concatenate([x, conv_features])
    x = double_conv_block(x, N_FILTERS)
    return x

# Feature Pyramid Network (FPN) block
def fpn_block(x, prev_feature_map=None, N_FILTERS=256):
    # 1x1 conv to reduce channels
    x = Conv2D(N_FILTERS, 1, padding="same", activation="gelu")(x)
    
    # If previous feature map exists, upsample and combine with current feature map
    if prev_feature_map is not None:
        # Upsample the previous feature map to match the current feature map's spatial dimensions
        prev_feature_map_upsampled = UpSampling2D(size=(2, 2))(prev_feature_map)
        
        # Apply a 1x1 conv to adjust the number of channels in the previous feature map (if necessary)
        prev_feature_map_upsampled = Conv2D(N_FILTERS, 1, padding="same", activation="gelu")(prev_feature_map_upsampled)
        
        # Now add the two feature maps
        x = Add()([x, prev_feature_map_upsampled])
    
    # Apply a 3x3 conv for smoothing and refine features
    x = Conv2D(N_FILTERS, 3, padding="same", activation="gelu")(x)
    return x

# %%
# U-Net Architecture with FPN only in the encoder path
inputs = Input(IMG_SHAPE)

# Encoder Path with downsampling
f1, p1 = downsample_block(inputs, 64)
f2, p2 = downsample_block(p1, 128)
f3, p3 = downsample_block(p2, 256)
f4, p4 = downsample_block(p3, 512)

# FPN applied only in the encoder (multiscale feature fusion)
f4 = fpn_block(f4, N_FILTERS=512)  # Apply FPN at the deepest encoder layer
f3 = fpn_block(f3, f4, N_FILTERS=256)  # Apply FPN with connection from f4
f2 = fpn_block(f2, f3, N_FILTERS=128)  # Apply FPN with connection from f3

# Bottleneck (unchanged)
bottleneck = double_conv_block(p4, 1024)

# Decoder Path (using original skip connections from encoder)
u6 = upsample_block(bottleneck, f4, 512)
u7 = upsample_block(u6, f3, 256)
u8 = upsample_block(u7, f2, 128)
u9 = upsample_block(u8, f1, 64)

# Output Layer (Segmentation)
outputs = Conv2D(N_CLASSES, 1, padding="same", activation="sigmoid")(u9)

# Create Model
unet_fpn_model = Model(inputs, outputs, name="U-Net-with-FPN-Encoder")

# Print model summary
unet_fpn_model.summary()

# Plot the Model (to visualize the updated FPN structure)
plot_model(unet_fpn_model, show_shapes=True, show_layer_names=True, dpi=120)
# Out:
# Model: "U-Net-with-FPN-Encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 224, 224,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 224, 224,  │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 112, 112,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 112, 112,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 112, 112,  │    147,584 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 56, 56,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 56, 56,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 56, 56,    │    590,080 │ conv2d_4[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 28, 28,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 28, 28,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 28, 28,    │  2,359,808 │ conv2d_6[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 14, 14,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 14, 14,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 14, 14,    │  9,438,208 │ conv2d_16[0][0]   │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 28, 28,    │    262,656 │ conv2d_7[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 28, 28,    │  4,719,104 │ conv2d_17[0][0]   │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 28, 28,    │  2,359,808 │ conv2d_8[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 28, 28,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ conv2d_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 56, 56,    │          0 │ conv2d_9[0][0]    │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 28, 28,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 56, 56,    │     65,792 │ conv2d_5[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 56, 56,    │    131,328 │ up_sampling2d[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 28, 28,    │  2,359,808 │ conv2d_18[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 56, 56,    │          0 │ conv2d_10[0][0],  │
# │                     │ 256)              │            │ conv2d_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 56, 56,    │  1,179,904 │ conv2d_19[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 56, 56,    │    590,080 │ add[0][0]         │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 56, 56,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 112, 112,  │          0 │ conv2d_12[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 56, 56,    │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 112, 112,  │     16,512 │ conv2d_3[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 112, 112,  │     32,896 │ up_sampling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 56, 56,    │    590,080 │ conv2d_20[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 112, 112,  │          0 │ conv2d_13[0][0],  │
# │                     │ 128)              │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 112, 112,  │    295,040 │ conv2d_21[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 112, 112,  │    147,584 │ add_1[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 112, 112,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 112, 112,  │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 112, 112,  │    147,584 │ conv2d_22[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 224, 224,  │     73,792 │ conv2d_23[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 224, 224,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 224, 224,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 224, 224,  │     36,928 │ conv2d_24[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 224, 224,  │         65 │ conv2d_25[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 38,120,001 (145.42 MB)
#  Trainable params: 38,120,001 (145.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Dice Coefficient
def dice_coefficient(y_true, y_pred, smooth=1.0):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

# Dice Loss
def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

# IoU Metric
def iou_metric(y_true, y_pred, smooth=1.0):
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true * y_pred), axis=[1, 2, 3])
    union = tf.keras.backend.sum(y_true, axis=[1, 2, 3]) + tf.keras.backend.sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.keras.backend.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

# %%
optimizer = Adam(learning_rate=LEARNING_RATE)
metrics = [
    'accuracy',
    'Precision',
    'Recall',
    iou_metric,
    dice_coefficient
]

unet_fpn_model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=metrics
)

callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, verbose=1),
    EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True),
    ModelCheckpoint(f'{EXPERIMENT_NAME}_best_model.keras', 
                   monitor='val_loss', 
                   save_best_only=True)
]

history = unet_fpn_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/35
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745825132.637204      97 service.cc:145] XLA service 0x7cbf240024e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745825132.637270      97 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1745825192.441264      97 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 668ms/step - Precision: 0.4872 - Recall: 0.2013 - accuracy: 0.9299 - dice_coefficient: 0.2704 - iou_metric: 0.1441 - loss: 0.6644
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745825258.060293      97 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion_14', 356 bytes spill stores, 356 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion_1', 648 bytes spill stores, 648 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion', 776 bytes spill stores, 752 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion_18', 356 bytes spill stores, 356 bytes spill loads
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - Precision: 0.4952 - Recall: 0.2091 - accuracy: 0.9304 - dice_coefficient: 0.2763 - iou_metric: 0.1480 - loss: 0.6534 - val_Precision: 0.8305 - val_Recall: 0.8466 - val_accuracy: 0.9721 - val_dice_coefficient: 0.7690 - val_iou_metric: 0.5254 - val_loss: 0.0692 - learning_rate: 0.0010
# Epoch 2/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 53s 741ms/step - Precision: 0.8381 - Recall: 0.8459 - accuracy: 0.9744 - dice_coefficient: 0.7637 - iou_metric: 0.5024 - loss: 0.0645 - val_Precision: 0.8938 - val_Recall: 0.8942 - val_accuracy: 0.9819 - val_dice_coefficient: 0.8444 - val_iou_metric: 0.5810 - val_loss: 0.0475 - learning_rate: 0.0010
# Epoch 3/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 53s 739ms/step - Precision: 0.9040 - Recall: 0.9020 - accuracy: 0.9848 - dice_coefficient: 0.8511 - iou_metric: 0.5795 - loss: 0.0399 - val_Precision: 0.8950 - val_Recall: 0.9434 - val_accuracy: 0.9857 - val_dice_coefficient: 0.8766 - val_iou_metric: 0.6465 - val_loss: 0.0372 - learning_rate: 0.0010
# Epoch 4/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 53s 739ms/step - Precision: 0.9155 - Recall: 0.9228 - accuracy: 0.9869 - dice_coefficient: 0.8772 - iou_metric: 0.6219 - loss: 0.0339 - val_Precision: 0.9479 - val_Recall: 0.8918 - val_accuracy: 0.9866 - val_dice_coefficient: 0.8835 - val_iou_metric: 0.6511 - val_loss: 0.0345 - learning_rate: 0.0010
# Epoch 5/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 53s 742ms/step - Precision: 0.9244 - Recall: 0.9300 - accuracy: 0.9882 - dice_coefficient: 0.8898 - iou_metric: 0.6361 - loss: 0.0302 - val_Precision: 0.9251 - val_Recall: 0.9285 - val_accuracy: 0.9875 - val_dice_coefficient: 0.8955 - val_iou_metric: 0.6577 - val_loss: 0.0322 - learning_rate: 0.0010
# Epoch 6/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 51s 712ms/step - Precision: 0.9262 - Recall: 0.9347 - accuracy: 0.9890 - dice_coefficient: 0.8957 - iou_metric: 0.6455 - loss: 0.0276 - val_Precision: 0.8931 - val_Recall: 0.9609 - val_accuracy: 0.9868 - val_dice_coefficient: 0.8995 - val_iou_metric: 0.6763 - val_loss: 0.0334 - learning_rate: 0.0010
# Epoch 7/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 53s 742ms/step - Precision: 0.9287 - Recall: 0.9384 - accuracy: 0.9894 - dice_coefficient: 0.9032 - iou_metric: 0.6654 - loss: 0.0264 - val_Precision: 0.9410 - val_Recall: 0.9352 - val_accuracy: 0.9895 - val_dice_coefficient: 0.9098 - val_iou_metric: 0.7052 - val_loss: 0.0259 - learning_rate: 0.0010
# Epoch 8/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 51s 712ms/step - Precision: 0.9349 - Recall: 0.9406 - accuracy: 0.9902 - dice_coefficient: 0.9083 - iou_metric: 0.6760 - loss: 0.0239 - val_Precision: 0.9380 - val_Recall: 0.9371 - val_accuracy: 0.9893 - val_dice_coefficient: 0.9074 - val_iou_metric: 0.7031 - val_loss: 0.0263 - learning_rate: 0.0010
# Epoch 9/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 53s 741ms/step - Precision: 0.9361 - Recall: 0.9420 - accuracy: 0.9900 - dice_coefficient: 0.9101 - iou_metric: 0.6847 - loss: 0.0243 - val_Precision: 0.9513 - val_Recall: 0.9242 - val_accuracy: 0.9895 - val_dice_coefficient: 0.9111 - val_iou_metric: 0.6994 - val_loss: 0.0258 - learning_rate: 0.0010
# Epoch 10/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 53s 740ms/step - Precision: 0.9369 - Recall: 0.9411 - accuracy: 0.9903 - dice_coefficient: 0.9114 - iou_metric: 0.6879 - loss: 0.0236 - val_Precision: 0.9401 - val_Recall: 0.9401 - val_accuracy: 0.9898 - val_dice_coefficient: 0.9157 - val_iou_metric: 0.7154 - val_loss: 0.0251 - learning_rate: 0.0010
# Epoch 11/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 53s 742ms/step - Precision: 0.9373 - Recall: 0.9414 - accuracy: 0.9903 - dice_coefficient: 0.9127 - iou_metric: 0.6903 - loss: 0.0237 - val_Precision: 0.9253 - val_Recall: 0.9597 - val_accuracy: 0.9899 - val_dice_coefficient: 0.9171 - val_iou_metric: 0.7236 - val_loss: 0.0245 - learning_rate: 0.0010
# Epoch 12/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 51s 712ms/step - Precision: 0.9383 - Recall: 0.9453 - accuracy: 0.9908 - dice_coefficient: 0.9157 - iou_metric: 0.6939 - loss: 0.0223 - val_Precision: 0.9251 - val_Recall: 0.9599 - val_accuracy: 0.9899 - val_dice_coefficient: 0.9187 - val_iou_metric: 0.7248 - val_loss: 0.0245 - learning_rate: 0.0010
# Epoch 13/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 51s 712ms/step - Precision: 0.9376 - Recall: 0.9449 - accuracy: 0.9904 - dice_coefficient: 0.9159 - iou_metric: 0.6998 - loss: 0.0233 - val_Precision: 0.9034 - val_Recall: 0.9739 - val_accuracy: 0.9889 - val_dice_coefficient: 0.9134 - val_iou_metric: 0.7154 - val_loss: 0.0274 - learning_rate: 0.0010
# Epoch 14/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 53s
35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 53s 741ms/step - Precision: 0.9468 - Recall: 0.9514 - accuracy: 0.9919 - dice_coefficient: 0.9258 - iou_metric: 0.7265 - loss: 0.0194 - val_Precision: 0.9453 - val_Recall: 0.9511 - val_accuracy: 0.9911 - val_dice_coefficient: 0.9265 - val_iou_metric: 0.7475 - val_loss: 0.0212 - learning_rate: 2.0000e-04
# Epoch 31/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 53s 741ms/step - Precision: 0.9463 - Recall: 0.9504 - accuracy: 0.9918 - dice_coefficient: 0.9255 - iou_metric: 0.7237 - loss: 0.0196 - val_Precision: 0.9468 - val_Recall: 0.9498 - val_accuracy: 0.9912 - val_dice_coefficient: 0.9251 - val_iou_metric: 0.7461 - val_loss: 0.0212 - learning_rate: 2.0000e-04
# Epoch 32/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 51s 712ms/step - Precision: 0.9463 - Recall: 0.9511 - accuracy: 0.9917 - dice_coefficient: 0.9259 - iou_metric: 0.7287 - loss: 0.0197 - val_Precision: 0.9508 - val_Recall: 0.9442 - val_accuracy: 0.9911 - val_dice_coefficient: 0.9263 - val_iou_metric: 0.7462 - val_loss: 0.0214 - learning_rate: 2.0000e-04
# Epoch 33/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 664ms/step - Precision: 0.9475 - Recall: 0.9498 - accuracy: 0.9919 - dice_coefficient: 0.9263 - iou_metric: 0.7284 - loss: 0.0192
# Epoch 33: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 51s 712ms/step - Precision: 0.9475 - Recall: 0.9498 - accuracy: 0.9919 - dice_coefficient: 0.9263 - iou_metric: 0.7283 - loss: 0.0192 - val_Precision: 0.9492 - val_Recall: 0.9461 - val_accuracy: 0.9911 - val_dice_coefficient: 0.9275 - val_iou_metric: 0.7489 - val_loss: 0.0214 - learning_rate: 2.0000e-04
# Epoch 34/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 53s 741ms/step - Precision: 0.9467 - Recall: 0.9493 - accuracy: 0.9919 - dice_coefficient: 0.9251 - iou_metric: 0.7284 - loss: 0.0193 - val_Precision: 0.9461 - val_Recall: 0.9509 - val_accuracy: 0.9912 - val_dice_coefficient: 0.9261 - val_iou_metric: 0.7473 - val_loss: 0.0211 - learning_rate: 4.0000e-05
# Epoch 35/35
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 53s 741ms/step - Precision: 0.9470 - Recall: 0.9514 - accuracy: 0.9919 - dice_coefficient: 0.9268 - iou_metric: 0.7302 - loss: 0.0193 - val_Precision: 0.9454 - val_Recall: 0.9518 - val_accuracy: 0.9912 - val_dice_coefficient: 0.9270 - val_iou_metric: 0.7483 - val_loss: 0.0211 - learning_rate: 4.0000e-05

# %% [markdown]
# # Results

# %%
# Get the best epochs for each metric
best_val_loss_epoch = np.argmin(history.history['val_loss']) + 1
best_val_dice_epoch = np.argmax(history.history['val_dice_coefficient']) + 1
best_val_iou_epoch = np.argmax(history.history['val_iou_metric']) + 1
best_val_acc_epoch = np.argmax(history.history['val_accuracy']) + 1

# Calculate the best metric values
min_val_loss = np.min(history.history['val_loss'])
max_val_dice = np.max(history.history['val_dice_coefficient'])
max_val_iou = np.max(history.history['val_iou_metric'])
max_val_acc = np.max(history.history['val_accuracy'])

# Plot Accuracy
plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'], 'b-', label='Training Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], 'r-', label='Validation Accuracy', linewidth=2)
plt.axvline(x=best_val_acc_epoch, color='g', linestyle='--', label=f'Best Epoch ({best_val_acc_epoch})')
plt.title('U-Net + FPN Model | Training and Validation Accuracy', fontsize=14, pad=15)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Plot Loss
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], 'b-', label='Training Loss', linewidth=2)
plt.plot(history.history['val_loss'], 'r-', label='Validation Loss', linewidth=2)
plt.axvline(x=best_val_loss_epoch, color='g', linestyle='--', label=f'Best Epoch ({best_val_loss_epoch})')
plt.title('U-Net + FPN Model | Training and Validation Loss', fontsize=14, pad=15)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Plot Dice Coefficient
plt.figure(figsize=(8, 6))
plt.plot(history.history['dice_coefficient'], 'b-', label='Training Dice', linewidth=2)
plt.plot(history.history['val_dice_coefficient'], 'r-', label='Validation Dice', linewidth=2)
plt.axvline(x=best_val_dice_epoch, color='g', linestyle='--', label=f'Best Epoch ({best_val_dice_epoch})')
plt.title('U-Net + FPN Model | Training and Validation Dice Coefficient', fontsize=14, pad=15)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Dice Coefficient', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Plot IoU
plt.figure(figsize=(8, 6))
plt.plot(history.history['iou_metric'], 'b-', label='Training IoU', linewidth=2)
plt.plot(history.history['val_iou_metric'], 'r-', label='Validation IoU', linewidth=2)
plt.axvline(x=best_val_iou_epoch, color='g', linestyle='--', label=f'Best Epoch ({best_val_iou_epoch})')
plt.title('U-Net + FPN Model | Training and Validation IoU Metric', fontsize=14, pad=15)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('IoU', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Print summary of best epochs and values
print("\nBest Epochs Summary:")
print("-" * 50)
print(f"Loss - Epoch: {best_val_loss_epoch:3d}, Value: {min_val_loss:.4f}")
print(f"Dice - Epoch: {best_val_dice_epoch:3d}, Value: {max_val_dice:.4f}")
print(f"IoU - Epoch: {best_val_iou_epoch:3d}, Value: {max_val_iou:.4f}")
print(f"Accuracy - Epoch: {best_val_acc_epoch:3d}, Value: {max_val_acc:.4f}")
# Out:
# Best Epochs Summary:
# --------------------------------------------------
# Loss - Epoch:  35, Value: 0.0211
# Dice - Epoch:  33, Value: 0.9275
# IoU - Epoch:  33, Value: 0.7489
# Accuracy - Epoch:  35, Value: 0.9912

# %%
def evaluate_model(model, X, y, batch_size=10):
    return model.evaluate(X, y, batch_size=batch_size, verbose=0)

# Store results for comparison
results_dict = {}
# Get evaluation results without printing
results_dict['train'] = evaluate_model(unet_fpn_model, X_train, y_train, batch_size=10)
results_dict['val'] = evaluate_model(unet_fpn_model, X_val, y_val, batch_size=10)
results_dict['test'] = evaluate_model(unet_fpn_model, X_test, y_test, batch_size=10)

# Create comparison table
metrics_names = ['Loss', 'Accuracy', 'Precision', 'Recall', 'IoU', 'Dice']
print("\nMetrics Comparison Across Datasets:")
print("-" * 65)
print(f"{'Metric':15} {'Training':15} {'Validation':15} {'Test':15}")
print("-" * 65)
for i, metric in enumerate(metrics_names):
    train_val = results_dict['train'][i]
    val_val = results_dict['val'][i]
    test_val = results_dict['test'][i]
    print(f"{metric:15} {train_val:15.4f} {val_val:15.4f} {test_val:15.4f}")
print("-" * 65)

# Visualize metrics comparison
plt.figure(figsize=(12, 6))
x = np.arange(len(metrics_names))
width = 0.25

plt.bar(x - width, results_dict['train'], width, label='Training', color='#7FC8A9')
plt.bar(x, results_dict['val'], width, label='Validation', color='#FFD166')
plt.bar(x + width, results_dict['test'], width, label='Test', color='#EF476F')

plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('U-Net + FPN Model Performance Comparison Across Datasets')
plt.xticks(x, metrics_names, rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Metrics Comparison Across Datasets:
# -----------------------------------------------------------------
# Metric          Training        Validation      Test
# -----------------------------------------------------------------
# Loss                     0.0193          0.0211          0.0196
# Accuracy                 0.9919          0.9912          0.9917
# Precision                0.9459          0.9454          0.9422
# Recall                   0.9519          0.9518          0.9475
# IoU                      0.7262          0.7534          0.7238
# Dice                     0.9251          0.9255          0.9199
# -----------------------------------------------------------------

# %%
# Calculate differences between datasets
def calculate_differences():
    datasets = ['Train', 'Val', 'Test']
    diff_matrix = np.zeros((len(metrics_names), len(datasets), len(datasets)))
    
    for i, metric in enumerate(metrics_names):
        for j, d1 in enumerate(datasets):
            for k, d2 in enumerate(datasets):
                if j != k:  # Skip comparing dataset with itself
                    d1_lower = d1.lower()
                    d2_lower = d2.lower()
                    diff = results_dict[d1_lower][i] - results_dict[d2_lower][i]
                    diff_matrix[i, j, k] = diff
    
    return diff_matrix

# Create heatmap for each metric
diff_matrix = calculate_differences()
datasets = ['Train', 'Val', 'Test']

# Create a figure with subplots for each metric
fig, axes = plt.subplots(2, 3, figsize=(20, 15))
axes = axes.ravel()

# Create heatmaps
for i, metric in enumerate(metrics_names):
    ax = axes[i]
    
    # Create heatmap data for this metric
    heatmap_data = diff_matrix[i]
    
    # Create mask for diagonal (self-comparison)
    mask = np.eye(len(datasets), dtype=bool)
    
    # Plot heatmap
    sns.heatmap(heatmap_data, 
                annot=True, 
                fmt='.4f', 
                cmap='RdBu_r',
                center=0,
                mask=mask,
                xticklabels=datasets,
                yticklabels=datasets,
                ax=ax,
                cbar_kws={'label': 'Difference'})
    
    ax.set_title(f'{metric} Differences')
    ax.set_xlabel('Dataset')
    ax.set_ylabel('Dataset')

plt.tight_layout()
plt.show()

# Print detailed analysis
print("\nDetailed Metrics Differences Analysis:")
print("-" * 70)
for i, metric in enumerate(metrics_names):
    print(f"\n{metric} Differences:")
    print("-" * 40)
    for j, d1 in enumerate(datasets):
        for k, d2 in enumerate(datasets):
            if j < k:  # Only print each comparison once
                diff = diff_matrix[i, j, k]
                print(f"{d1} vs {d2}: {diff:+.4f}")
                if abs(diff) > 0.1:  # Flag significant differences
                    print(f"   ⚠️ Large difference detected!")
                    if diff > 0:
                        print(f"   • {d1} performs better than {d2}")
                    else:
                        print(f"   • {d2} performs better than {d1}")
# Out:
# Detailed Metrics Differences Analysis:
# ----------------------------------------------------------------------
#
# Loss Differences:
# ----------------------------------------
# Train vs Val: -0.0017
# Train vs Test: -0.0003
# Val vs Test: +0.0014
#
# Accuracy Differences:
# ----------------------------------------
# Train vs Val: +0.0007
# Train vs Test: +0.0002
# Val vs Test: -0.0005
#
# Precision Differences:
# ----------------------------------------
# Train vs Val: +0.0005
# Train vs Test: +0.0037
# Val vs Test: +0.0032
#
# Recall Differences:
# ----------------------------------------
# Train vs Val: +0.0001
# Train vs Test: +0.0043
# Val vs Test: +0.0042
#
# IoU Differences:
# ----------------------------------------
# Train vs Val: -0.0271
# Train vs Test: +0.0024
# Val vs Test: +0.0296
#
# Dice Differences:
# ----------------------------------------
# Train vs Val: -0.0005
# Train vs Test: +0.0052
# Val vs Test: +0.0056

# %%
def visualize_prediction(model, X_test, y_test, idx=None):
    if idx is None:
        idx = np.random.randint(0, len(X_test))
    
    test_img = X_test[idx]
    test_mask = y_test[idx]
    
    # Make prediction
    test_pred = model.predict(test_img[np.newaxis, ...])
    test_pred_binary = (test_pred > 0.5).astype(np.uint8)
    
    # Create figure
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
    
    # Original image
    ax1.imshow(test_img[..., 0], cmap='gray')
    ax1.set_title('Original Image')
    ax1.axis('off')
    
    # Ground truth mask
    ax2.imshow(test_mask[..., 0], cmap='gray')
    ax2.set_title('Ground Truth Mask')
    ax2.axis('off')
    
    # Predicted mask
    pred_display = ax3.imshow(test_pred[0, ..., 0], cmap='magma')
    ax3.set_title('Predicted Mask')
    ax3.axis('off')
    
    # Add colorbar
    plt.colorbar(pred_display, ax=ax3)
    
    plt.tight_layout()
    plt.show()
    
    # Convert masks to float32 for metric calculation
    test_mask_float = tf.cast(test_mask, tf.float32)
    test_pred_float = tf.cast(test_pred, tf.float32)
    
    # Calculate metrics for this prediction
    dice = dice_coefficient(
        test_mask_float[np.newaxis, ...], 
        test_pred_float
    ).numpy()
    
    iou = iou_metric(
        test_mask_float[np.newaxis, ...], 
        test_pred_float
    ).numpy()
    
    print(f"Dice coefficient for this prediction: {dice:.4f}")
    print(f"IoU for this prediction: {iou:.4f}")

# Update the metric functions to ensure type consistency
def dice_coefficient(y_true, y_pred, smooth=1.0):
    # Ensure inputs are float32
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

def iou_metric(y_true, y_pred, smooth=1.0):
    # Ensure inputs are float32
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true * y_pred), axis=[1, 2, 3])
    union = tf.keras.backend.sum(y_true, axis=[1, 2, 3]) + tf.keras.backend.sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.keras.backend.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

# Visualize a random prediction
visualize_prediction(unet_fpn_model, X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Dice coefficient for this prediction: 0.9066
# IoU for this prediction: 0.8293

# %%
def visualize_prediction(model, X_test, y_test, idx=None):
    if idx is None:
        idx = np.random.randint(0, len(X_test))
    
    test_img = X_test[idx]
    test_mask = y_test[idx]
    
    # Make prediction
    test_pred = model.predict(test_img[np.newaxis, ...])
    test_pred_binary = (test_pred > 0.5).astype(np.uint8)
    
    # Create figure
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
    
    # Original image
    ax1.imshow(test_img[..., 0], cmap='gray')
    ax1.set_title('Original Image')
    ax1.axis('off')
    
    # Ground truth mask
    ax2.imshow(test_mask[..., 0], cmap='gray')
    ax2.set_title('Ground Truth Mask')
    ax2.axis('off')
    
    # Predicted mask
    pred_display = ax3.imshow(test_pred[0, ..., 0], cmap='magma')
    ax3.set_title('Predicted Mask')
    ax3.axis('off')
    
    # Add colorbar
    plt.colorbar(pred_display, ax=ax3)
    
    plt.tight_layout()
    plt.show()
    
    # Convert masks to float32 for metric calculation
    test_mask_float = tf.cast(test_mask, tf.float32)
    test_pred_float = tf.cast(test_pred, tf.float32)
    
    # Calculate metrics for this prediction
    dice = dice_coefficient(
        test_mask_float[np.newaxis, ...], 
        test_pred_float
    ).numpy()
    
    iou = iou_metric(
        test_mask_float[np.newaxis, ...], 
        test_pred_float
    ).numpy()
    
    print(f"Dice coefficient for this prediction: {dice:.4f}")
    print(f"IoU for this prediction: {iou:.4f}")

# Update the metric functions to ensure type consistency
def dice_coefficient(y_true, y_pred, smooth=1.0):
    # Ensure inputs are float32
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

def iou_metric(y_true, y_pred, smooth=1.0):
    # Ensure inputs are float32
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true * y_pred), axis=[1, 2, 3])
    union = tf.keras.backend.sum(y_true, axis=[1, 2, 3]) + tf.keras.backend.sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.keras.backend.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

# Visualize a random prediction
visualize_prediction(unet_fpn_model, X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Dice coefficient for this prediction: 0.5447
# IoU for this prediction: 0.3756

# %% [markdown]
# # Save Model

# %%
unet_fpn_model.save('UNet_fpn_model.h5')

# %%
unet_fpn_model.save('UNet_fpn_model.keras')

# %%
def visualize_prediction(model, X_test, y_test, idx):
    if idx is None:
        raise ValueError("Index of the sample image must be provided.")
    
    test_img = X_test[idx]
    test_mask = y_test[idx]
    
    # Make prediction
    test_pred = model.predict(test_img[np.newaxis, ...])
    test_pred_binary = (test_pred > 0.5).astype(np.uint8)
    
    # Create figure
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
    
    # Original image
    ax1.imshow(test_img[..., 0], cmap='gray')
    ax1.set_title('Original Image')
    ax1.axis('off')
    
    # Ground truth mask
    ax2.imshow(test_mask[..., 0], cmap='gray')
    ax2.set_title('Ground Truth Mask')
    ax2.axis('off')
    
    # Predicted mask
    pred_display = ax3.imshow(test_pred[0, ..., 0], cmap='magma')
    ax3.set_title('Predicted Mask')
    ax3.axis('off')
    
    # Add colorbar
    plt.colorbar(pred_display, ax=ax3)
    
    plt.tight_layout()
    plt.show()
    
    # Convert masks to float32 for metric calculation
    test_mask_float = tf.cast(test_mask, tf.float32)
    test_pred_float = tf.cast(test_pred, tf.float32)
    
    # Calculate metrics for this prediction
    dice = dice_coefficient(
        test_mask_float[np.newaxis, ...], 
        test_pred_float
    ).numpy()
    
    iou = iou_metric(
        test_mask_float[np.newaxis, ...], 
        test_pred_float
    ).numpy()
    
    print(f"Dice coefficient for this prediction: {dice:.4f}")
    print(f"IoU for this prediction: {iou:.4f}")

# Update the metric functions to ensure type consistency
def dice_coefficient(y_true, y_pred, smooth=1.0):
    # Ensure inputs are float32
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

def iou_metric(y_true, y_pred, smooth=1.0):
    # Ensure inputs are float32
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true * y_pred), axis=[1, 2, 3])
    union = tf.keras.backend.sum(y_true, axis=[1, 2, 3]) + tf.keras.backend.sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.keras.backend.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

# Visualize a specific prediction
visualize_prediction(unet_fpn_model, X_test, y_test, idx=80)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Dice coefficient for this prediction: 0.8188
# IoU for this prediction: 0.6933
